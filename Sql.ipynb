# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %% [markdown]
# Load cleaned CSV file:

# %%
df = pd.read_csv("cleaned_luxury_housing.csv")

# %%
df
# Out:
#        Property_ID       Micro_Market Project_Name Developer_Name  \
# 0       PROP000001      SARJAPUR ROAD    Project_0            RMZ
# 1       PROP000002        INDIRANAGAR    Project_1    PURAVANKARA
# 2       PROP000003  BANNERGHATTA ROAD    Project_2   TATA HOUSING
# 3       PROP000004       BELLARY ROAD    Project_3        EMBASSY
# 4       PROP000005        KORAMANGALA    Project_4        SNN RAJ
# ...            ...                ...          ...            ...
# 100995  PROP004730       BELLARY ROAD  Project_229        EMBASSY
# 100996  PROP059810       BELLARY ROAD  Project_309        BRIGADE
# 100997  PROP065099        HENNUR ROAD   Project_98            RMZ
# 100998  PROP093022        RAJAJINAGAR   Project_21        EMBASSY
# 100999  PROP023826         WHITEFIELD  Project_325     L&T REALTY
#
#         Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type  \
# 0               4025.0          4BHK        12.750846          Primary
# ...

# %% [markdown]
# Create DB connection:

# %%
engine = create_engine("postgresql+psycopg2://postgres:Karan7826@localhost:5432/luxury_db")

# %%
df.to_sql("luxury_house", con=engine, if_exists="replace", index=False)
# Out:
# 1000

# %%
pd.read_sql('SELECT "Transaction_Type", "Booking_Flag" FROM luxury_house LIMIT 10;', engine)
# Out:
#   Transaction_Type  Booking_Flag
# 0          Primary             1
# 1          Primary             1
# 2          Primary             1
# 3          Primary             1
# 4        Secondary             0
# 5        Secondary             0
# 6        Secondary             0
# 7        Secondary             0
# 8        Secondary             0
# 9          Primary             1

# %%
pd.read_sql("SELECT * FROM luxury_house LIMIT 10;", engine)
# Out:
#   Property_ID       Micro_Market Project_Name     Developer_Name  \
# 0  PROP000001      SARJAPUR ROAD    Project_0                RMZ
# 1  PROP000002        INDIRANAGAR    Project_1        PURAVANKARA
# 2  PROP000003  BANNERGHATTA ROAD    Project_2       TATA HOUSING
# 3  PROP000004       BELLARY ROAD    Project_3            EMBASSY
# 4  PROP000005        KORAMANGALA    Project_4            SNN RAJ
# 5  PROP000006          YELAHANKA    Project_5            BRIGADE
# 6  PROP000007  BANNERGHATTA ROAD    Project_6           PRESTIGE
# 7  PROP000008         WHITEFIELD    Project_7  TOTAL ENVIRONMENT
# 8  PROP000009      SARJAPUR ROAD    Project_8           PRESTIGE
# 9  PROP000010           JP NAGAR    Project_9        PURAVANKARA
#
#    Unit_Size_Sqft Configuration  Ticket_Price_Cr Transaction_Type Buyer_Type  \
# 0          4025.0          4BHK        12.750846          Primary        NRI
# 1          5760.0          3BHK        16.292152          Primary      Other
# ...

# %%
pd.read_sql("""
SELECT "Micro_Market", 
AVG("Ticket_Price_Cr") AS avg_price
FROM luxury_house
GROUP BY "Micro_Market"
ORDER BY avg_price DESC
LIMIT 10;
""", engine)
# Out:
#         Micro_Market  avg_price
# 0      SARJAPUR ROAD  12.835822
# 1             HEBBAL  12.780053
# 2        HENNUR ROAD  12.682557
# 3  BANNERGHATTA ROAD  12.677015
# 4            MG ROAD  12.673694
# 5        KORAMANGALA  12.673545
# 6          JAYANAGAR  12.660273
# 7           JP NAGAR  12.651805
# 8          YELAHANKA  12.632407
# 9        INDIRANAGAR  12.616555

# %%
pd.read_sql("""
SELECT "Developer_Name", 
AVG("Ticket_Price_Cr") AS avg_price
FROM luxury_house
GROUP BY "Developer_Name"
ORDER BY avg_price DESC
LIMIT 10;
""", engine)
# Out:
#       Developer_Name  avg_price
# 0              SOBHA  12.796678
# 1  TOTAL ENVIRONMENT  12.747614
# 2         L&T REALTY  12.712636
# 3             GODREJ  12.688487
# 4                RMZ  12.671626
# 5        PURAVANKARA  12.665814
# 6           PRESTIGE  12.643322
# 7       TATA HOUSING  12.604211
# 8            SNN RAJ  12.549005
# 9            BRIGADE  12.544106

# %%
pd.read_sql("""
SELECT "Configuration", 
AVG("Price_per_Sqft") AS avg_price_sqft
FROM luxury_house
GROUP BY "Configuration"
ORDER BY avg_price_sqft DESC;
""", engine)
# Out:
#   Configuration  avg_price_sqft
# 0         5BHK+  -568102.536298
# 1          4BHK  -598119.587560
# 2          3BHK  -659583.704479

# %%
pd.read_sql("""
SELECT "Quarter_Number", 
COUNT(*) AS total_properties
FROM luxury_house
GROUP BY "Quarter_Number"
ORDER BY "Quarter_Number";
""", engine)
# Out:
#    Quarter_Number  total_properties
# 0               1             25281
# 1               2             25263
# 2               3             25301
# 3               4             25155

# %%
pd.read_sql("""
SELECT "Transaction_Type", 
COUNT(*) AS count
FROM luxury_house
GROUP BY "Transaction_Type";
""", engine)
# Out:
#   Transaction_Type  count
# 0          Primary  50494
# 1        Secondary  50506

# %%
pd.read_sql("SELECT * FROM luxury_house LIMIT 5;", engine)
# Out:
#   Property_ID       Micro_Market Project_Name Developer_Name  Unit_Size_Sqft  \
# 0  PROP000001      SARJAPUR ROAD    Project_0            RMZ          4025.0
# 1  PROP000002        INDIRANAGAR    Project_1    PURAVANKARA          5760.0
# 2  PROP000003  BANNERGHATTA ROAD    Project_2   TATA HOUSING          7707.0
# 3  PROP000004       BELLARY ROAD    Project_3        EMBASSY          6192.0
# 4  PROP000005        KORAMANGALA    Project_4        SNN RAJ          7147.0
#
#   Configuration  Ticket_Price_Cr Transaction_Type Buyer_Type Purchase_Quarter  \
# 0          4BHK        12.750846          Primary        NRI       2025-03-31
# 1          3BHK        16.292152          Primary      Other       2024-06-30
# 2          4BHK        10.517724          Primary        HNI       2023-12-31
# 3          3BHK         9.396367          Primary        HNI       2024-03-31
# 4          4BHK        15.345392        Secondary        HNI       2024-12-31
#
# ...

# %%
pd.read_sql("SELECT * FROM luxury_house LIMIT 5;", engine)
# Out:
#   Property_ID       Micro_Market Project_Name Developer_Name  Unit_Size_Sqft  \
# 0  PROP000001      SARJAPUR ROAD    Project_0            RMZ          4025.0
# 1  PROP000002        INDIRANAGAR    Project_1    PURAVANKARA          5760.0
# 2  PROP000003  BANNERGHATTA ROAD    Project_2   TATA HOUSING          7707.0
# 3  PROP000004       BELLARY ROAD    Project_3        EMBASSY          6192.0
# 4  PROP000005        KORAMANGALA    Project_4        SNN RAJ          7147.0
#
#   Configuration  Ticket_Price_Cr Transaction_Type Buyer_Type Purchase_Quarter  \
# 0          4BHK        12.750846          Primary        NRI       2025-03-31
# 1          3BHK        16.292152          Primary      Other       2024-06-30
# 2          4BHK        10.517724          Primary        HNI       2023-12-31
# 3          3BHK         9.396367          Primary        HNI       2024-03-31
# 4          4BHK        15.345392        Secondary        HNI       2024-12-31
#
# ...

# %%
df["Booking_Flags"] = df["Transaction_Type"].map({"Primary": 1, "Secondary": 0})

# %%
pd.read_sql('SELECT "Booking_Flag" FROM luxury_house LIMIT 5;', engine)
# Out:
#    Booking_Flag
# 0             1
# 1             1
# 2             1
# 3             1
# 4             0

# %%
pd.read_sql("""
SELECT column_name
FROM information_schema.columns
WHERE table_name = 'luxury_house';
""", engine)
# Out:
#              column_name
# 0           Booking_Flag
# 1         Unit_Size_Sqft
# 2        Ticket_Price_Cr
# 3     Connectivity_Score
# 4          Amenity_Score
# 5   Locality_Infra_Score
# 6   Avg_Traffic_Time_Min
# 7         Price_per_Sqft
# 8         Quarter_Number
# 9       Purchase_Quarter
# 10             NRI_Buyer
# 11           Property_ID
# 12          Micro_Market
# 13          Project_Name
# 14        Developer_Name
# 15     Possession_Status
# 16         Configuration
# 17         Sales_Channel
# 18      Transaction_Type
# 19            Buyer_Type

# %%
pd.read_sql('SELECT "Transaction_Type", "Booking_Flag" FROM luxury_house LIMIT 10;', engine)
# Out:
#   Transaction_Type  Booking_Flag
# 0          Primary             1
# 1          Primary             1
# 2          Primary             1
# 3          Primary             1
# 4        Secondary             0
# 5        Secondary             0
# 6        Secondary             0
# 7        Secondary             0
# 8        Secondary             0
# 9          Primary             1

# %% [markdown]
# Upload data to PostgreSQL:
